# %%
import numpy as np
from gth_solve_jit import gth_solve, gth_solve_jit

# %%
A = [[0.4, 0.6], [0.2, 0.8]]

# %%
gth_solve(A)
# Out:
# array([ 0.25,  0.75])

# %%
gth_solve_jit(A)
# Out:
# array([ 0.25,  0.75])

# %%
def random_probvec(k, m):
    """
    Create probability vectors.
    Parameters
    ----------
    k : scalar(int)
        Dimension of each probability vectors.
    m : scalar(int)
        Number of probability vectors.
    Returns
    -------
    ndarray(float, ndim=2)
        Array of shape (m, k) containing probability vectors as rows.
    """
    x = np.empty((m, k+1))
    r = np.random.rand(m, k-1)
    r.sort(axis=-1)
    x[:, 0], x[:, 1:k], x[:, k] = 0, r, 1
    return np.diff(x, axis=-1)

# %%
random_probvec(2, 2)
# Out:
# array([[ 0.83065745,  0.16934255],
#        [ 0.68162135,  0.31837865]])

# %%
sizes = [10, 50, 100, 1000]
rand_matrices = []

for n in sizes:
    Q = random_probvec(n, n)
    rand_matrices.append(Q)

# %%
for i, Q in enumerate(rand_matrices):
    print 'rand_matrices[{0}] ({1} x {2})'.format(i, Q.shape[0], Q.shape[1])
    # %timeit gth_solve(Q)
    # %timeit gth_solve_jit(Q)
# Out:
# rand_matrices[0] (10 x 10)
# 1000 loops, best of 3: 230 µs per loop
# 1 loops, best of 3: 17.9 µs per loop
# rand_matrices[1] (50 x 50)
# 1000 loops, best of 3: 1.44 ms per loop
# 10000 loops, best of 3: 95.8 µs per loop
# rand_matrices[2] (100 x 100)
# 100 loops, best of 3: 4.25 ms per loop
# 1000 loops, best of 3: 631 µs per loop
# rand_matrices[3] (1000 x 1000)
# 1 loops, best of 3: 1.63 s per loop
# 1 loops, best of 3: 599 ms per loop

# %%
import platform
print platform.platform()
# Out:
# Darwin-10.8.0-i386-64bit

# %%
import sys
print sys.version
# Out:
# 2.7.8 (default, Aug 12 2014, 11:32:49)
# [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]

# %%
print np.__version__
# Out:
# 1.9.2

# %%
import numba
print numba.__version__
# Out:
# 0.15.1

# %%
gth_solve_jit.inspect_types()
# Out:
# gth_solve_jit (array(float64, 2d, C, nonconst),)
# --------------------------------------------------------------------------------
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#     # label 0
#     #   A.1 = A  :: pyobject
#     #   del A
#     #   $0.1 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $0.2 = getattr(attr=array, value=$0.1)  :: pyobject
#     #   del $0.1
#     #   $0.5 = global(float: <type 'float'>)  :: pyobject
#     #   $0.6 = call $0.2(A.1, dtype=$0.5)  :: pyobject
#     #   del A.1
#     #   del $0.5
#     #   del $0.2
#     #   A1 = $0.6  :: pyobject
#     #   del $0.6
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#     #   $0.7 = global(len: <built-in function len>)  :: pyobject
#     #   $0.9 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $0.10 = call $0.7($0.9, )  :: pyobject
#     #   del $0.9
#     #   del $0.7
#     #   $const0.11 = const(int, 2)  :: pyobject
#     #   $0.12 = $0.10 != $const0.11  :: pyobject
#     #   del $const0.11
#     #   del $0.10
#     #   branch $0.12, 68, 42
#     # label 42
#     #   $42.2 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const42.3 = const(int, 0)  :: pyobject
#     #   $42.4 = getitem(index=$const42.3, value=$42.2)  :: pyobject
#     #   del $const42.3
#     #   del $42.2
#     #   $42.6 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const42.7 = const(int, 1)  :: pyobject
#     #   $42.8 = getitem(index=$const42.7, value=$42.6)  :: pyobject
#     #   del $const42.7
#     #   del $42.6
#     #   $42.9 = $42.4 != $42.8  :: pyobject
#     #   del $42.8
#     #   del $42.4
#     #   branch $42.9, 68, 77
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#         # label 68
#         #   del A1
#         #   del $42.9
#         #   del $0.12
#         #   $68.1 = global(ValueError: <type 'exceptions.ValueError'>)  :: pyobject
#         #   del $68.1
#         #   raise <type 'exceptions.ValueError'>
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#     # label 77
#     #   del $42.9
#     #   del $0.12
#     #   $77.2 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const77.3 = const(int, 0)  :: pyobject
#     #   $77.4 = getitem(index=$const77.3, value=$77.2)  :: pyobject
#     #   del $const77.3
#     #   del $77.2
#     #   n = $77.4  :: pyobject
#     #   del $77.4
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#     #   $77.5 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $77.6 = getattr(attr=zeros, value=$77.5)  :: pyobject
#     #   del $77.5
#     #   $77.8 = call $77.6(n, )  :: pyobject
#     #   del $77.6
#     #   x = $77.8  :: pyobject
#     #   del $77.8
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#     # label 108.1
#     #   $const108.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $108.1.4 = call $const108.1.1(A1, n, )  :: pyobject
#     #   del $const108.1.1
#     #   del $108.1.4
#     #   jump 295
#     #   jump 108.1
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#     # label 295
#     #   $const295.1 = const(int, 1)  :: pyobject
#     #   $const295.4 = const(int, 1)  :: pyobject
#     #   $295.5 = n - $const295.4  :: pyobject
#     #   del $const295.4
#     #   x[$295.5] = $const295.1  :: pyobject
#     #   del $const295.1
#     #   del $295.5
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#     #   jump 312.1
#     # label 312.1
#     #   $const312.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $312.1.5 = call $const312.1.1(A1, x, n, )  :: pyobject
#     #   del A1
#     #   del $const312.1.1
#     #   del $312.1.5
#     #   jump 406
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#     # label 406
#     #   $406.1 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $406.2 = getattr(attr=sum, value=$406.1)  :: pyobject
#     #   del $406.1
#     #   $406.4 = call $406.2(x, )  :: pyobject
#     #   del $406.2
#     #   norm = $406.4  :: pyobject
#     #   del $406.4
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#     # label 424.1
#     #   $const424.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $424.1.5 = call $const424.1.1(x, norm, n, )  :: pyobject
#     #   del norm
#     #   del n
#     #   del $const424.1.1
#     #   del $424.1.5
#     #   jump 460
#     #   jump 424.1
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#     # label 460
#     #   $460.2 = cast(value=x)  :: pyobject
#     #   del x
#     #   return $460.2
#
#     return x
#
# # The function contains lifted loops
# # Loop at line 116
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#     # label 105
#     #   A1.1 = A1  :: array(float64, 2d, C, nonconst)
#     #   del A1
#     #   n.1 = n  :: int64
#     #   del n
#     #   $105.1 = global(range: <built-in function range>)  :: range
#     #   $const105.3 = const(int, 1)  :: int32
#     #   $105.4 = n.1 - $const105.3  :: int64
#     #   del $const105.3
#     #   $105.5 = call $105.1($105.4, )  :: (int64,) -> range_state64
#     #   del $105.4
#     #   del $105.1
#     #   $105.6 = getiter(value=$105.5)  :: range_iter64
#     #   del $105.5
#     #   $phi122.1 = $105.6  :: range_iter64
#     #   del $105.6
#     #   jump 122
#     # label 125
#     #   k = $phi125.1  :: int64
#     #   del $phi125.1
#     # label 122
#     #   $122.2 = iternext(value=$phi122.1)  :: pair<int64, bool>
#     #   $122.3 = pair_first(value=$122.2)  :: int64
#     #   $122.4 = pair_second(value=$122.2)  :: bool
#     #   del $122.2
#     #   $phi125.1 = $122.3  :: int64
#     #   del $122.3
#     #   branch $122.4, 125, 294
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#         #   $125.2 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: Module(<module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)
#         #   $125.3 = getattr(attr=sum, value=$125.2)  :: Function(<unbound method Numpy_reduce_<function sum at 0x103db1848>.sum>)
#         #   del $125.2
#         #   $k125.5 = k  :: int64
#         #   $const125.7 = const(int, 1)  :: int32
#         #   $125.8 = k + $const125.7  :: int64
#         #   del $const125.7
#         #   $125.10 = global(slice: <type 'slice'>)  :: slice
#         #   $125.11 = call $125.10($125.8, n.1, )  :: (int64, int64) -> slice3_type
#         #   del $125.8
#         #   del $125.10
#         #   $125.12 = build_tuple(items=[Var($k125.5, gth_solve_jit.py (117)), Var($125.11, gth_solve_jit.py (117))])  :: (int64, slice3_type)
#         #   del $k125.5
#         #   del $125.11
#         #   $125.13 = getitem(index=$125.12, value=A1.1)  :: array(float64, 1d, A, nonconst)
#         #   del $125.12
#         #   $125.14 = call $125.3($125.13, )  :: (array(float64, 1d, A, nonconst),) -> float64
#         #   del $125.3
#         #   del $125.13
#         #   scale = $125.14  :: float64
#         #   del $125.14
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#         # label 163
#         #   $163.1 = global(range: <built-in function range>)  :: range
#         #   $const163.3 = const(int, 1)  :: int32
#         #   $163.4 = k + $const163.3  :: int64
#         #   del $const163.3
#         #   $163.6 = call $163.1($163.4, n.1, )  :: (int64, int64) -> range_state64
#         #   del $163.4
#         #   del $163.1
#         #   $163.7 = getiter(value=$163.6)  :: range_iter64
#         #   del $163.6
#         #   $phi183.1 = $163.7  :: range_iter64
#         #   del $163.7
#         #   jump 183
#         #   jump 163
#         # label 183
#         #   $183.2 = iternext(value=$phi183.1)  :: pair<int64, bool>
#         #   $183.3 = pair_first(value=$183.2)  :: int64
#         #   $183.4 = pair_second(value=$183.2)  :: bool
#         #   del $183.2
#         #   $phi186.1 = $183.3  :: int64
#         #   del $183.3
#         #   branch $183.4, 186, 290
#         # label 186
#         #   i = $phi186.1  :: int64
#         #   del $phi186.1
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#             #   $A1186.2 = A1.1  :: array(float64, 2d, C, nonconst)
#             #   $186.5 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(k, gth_solve_jit.py (116))])  :: (int64 x 2)
#             #   $186.8 = getitem(index=$186.5, value=A1.1)  :: float64
#             #   $186.10 = inplace_binop(rhs=scale, lhs=$186.8, fn=/?)  :: float64
#             #   del $186.8
#             #   $A1186.2[$186.5] = $186.10  :: (array(float64, 2d, C, nonconst), (int64 x 2), float64) -> none
#             #   del $A1186.2
#             #   del $186.5
#             #   del $186.10
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#             # label 231
#             #   $231.2 = iternext(value=$phi231.1)  :: pair<int64, bool>
#             #   $231.3 = pair_first(value=$231.2)  :: int64
#             #   $231.4 = pair_second(value=$231.2)  :: bool
#             #   del $231.2
#             #   $phi234.1 = $231.3  :: int64
#             #   del $231.3
#             #   branch $231.4, 234, 286
#             # label 234
#             #   j = $phi234.1  :: int64
#             #   del $phi234.1
#             # label 211
#             #   $211.1 = global(range: <built-in function range>)  :: range
#             #   $const211.3 = const(int, 1)  :: int32
#             #   $211.4 = k + $const211.3  :: int64
#             #   del $const211.3
#             #   $211.6 = call $211.1($211.4, n.1, )  :: (int64, int64) -> range_state64
#             #   del $211.4
#             #   del $211.1
#             #   $211.7 = getiter(value=$211.6)  :: range_iter64
#             #   del $211.6
#             #   $phi231.1 = $211.7  :: range_iter64
#             #   del $211.7
#             #   jump 231
#             #   jump 211
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#                 # label 290
#                 #   del scale
#                 #   del k
#                 #   del $phi186.1
#                 #   del $phi183.1
#                 #   del $183.4
#                 #   jump 291
#                 # label 294
#                 #   del n.1
#                 #   del A1.1
#                 #   del $phi125.1
#                 #   del $phi122.1
#                 #   del $122.4
#                 #   jump 295
#                 #   $A1234.2 = A1.1  :: array(float64, 2d, C, nonconst)
#                 #   $234.5 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(j, gth_solve_jit.py (127))])  :: (int64 x 2)
#                 #   $234.8 = getitem(index=$234.5, value=A1.1)  :: float64
#                 #   $234.12 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(k, gth_solve_jit.py (116))])  :: (int64 x 2)
#                 #   $234.13 = getitem(index=$234.12, value=A1.1)  :: float64
#                 #   del $234.12
#                 #   $234.17 = build_tuple(items=[Var(k, gth_solve_jit.py (116)), Var(j, gth_solve_jit.py (127))])  :: (int64 x 2)
#                 #   del j
#                 #   $234.18 = getitem(index=$234.17, value=A1.1)  :: float64
#                 #   del $234.17
#                 #   $234.19 = $234.13 * $234.18  :: float64
#                 #   del $234.18
#                 #   del $234.13
#                 #   $234.20 = inplace_binop(rhs=$234.19, lhs=$234.8, fn=+)  :: float64
#                 #   del $234.8
#                 #   del $234.19
#                 #   $A1234.2[$234.5] = $234.20  :: (array(float64, 2d, C, nonconst), (int64 x 2), float64) -> none
#                 #   del $A1234.2
#                 #   del $234.5
#                 #   del $234.20
#                 #   jump 231
#                 # label 295
#                 #   $const295.1 = const(NoneType, None)  :: none
#                 #   $295.2 = cast(value=$const295.1)  :: none
#                 #   del $const295.1
#                 #   return $295.2
#                 # label 291
#                 #   jump 122
#                 # label 286
#                 #   del i
#                 #   del $phi234.1
#                 #   del $phi231.1
#                 #   del $231.4
#                 #   jump 287
#                 # label 287
#                 #   jump 183
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
# # Loop at line 132
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#     # label 332
#     #   $332.2 = iternext(value=$phi332.1)  :: pair<int64, bool>
#     #   $332.3 = pair_first(value=$332.2)  :: int64
#     #   $332.4 = pair_second(value=$332.2)  :: bool
#     #   del $332.2
#     #   $phi335.1 = $332.3  :: int64
#     #   del $332.3
#     #   branch $332.4, 335, 405
#     # label 335
#     #   k = $phi335.1  :: int64
#     #   del $phi335.1
#     # label 309
#     #   A1.1 = A1  :: array(float64, 2d, C, nonconst)
#     #   del A1
#     #   x.1 = x  :: array(float64, 1d, C, nonconst)
#     #   del x
#     #   n.1 = n  :: int64
#     #   del n
#     #   $309.1 = global(range: <built-in function range>)  :: range
#     #   $const309.3 = const(int, 2)  :: int32
#     #   $309.4 = n.1 - $const309.3  :: int64
#     #   del $const309.3
#     #   $const309.5 = const(int, -1)  :: int32
#     #   $const309.6 = const(int, -1)  :: int32
#     #   $309.7 = call $309.1($309.4, $const309.5, $const309.6, )  :: (int64, int64, int64) -> range_state64
#     #   del $const309.6
#     #   del $const309.5
#     #   del $309.4
#     #   del $309.1
#     #   $309.8 = getiter(value=$309.7)  :: range_iter64
#     #   del $309.7
#     #   $phi332.1 = $309.8  :: range_iter64
#     #   del $309.8
#     #   jump 332
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#         # label 358
#         #   $358.2 = iternext(value=$phi358.1)  :: pair<int64, bool>
#         #   $358.3 = pair_first(value=$358.2)  :: int64
#         #   $358.4 = pair_second(value=$358.2)  :: bool
#         #   del $358.2
#         #   $phi361.1 = $358.3  :: int64
#         #   del $358.3
#         #   branch $358.4, 361, 401
#         # label 361
#         #   i = $phi361.1  :: int64
#         #   del $phi361.1
#         #   jump 338
#         # label 338
#         #   $338.1 = global(range: <built-in function range>)  :: range
#         #   $const338.3 = const(int, 1)  :: int32
#         #   $338.4 = k + $const338.3  :: int64
#         #   del $const338.3
#         #   $338.6 = call $338.1($338.4, n.1, )  :: (int64, int64) -> range_state64
#         #   del $338.4
#         #   del $338.1
#         #   $338.7 = getiter(value=$338.6)  :: range_iter64
#         #   del $338.6
#         #   $phi358.1 = $338.7  :: range_iter64
#         #   del $338.7
#         #   jump 358
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#             #   $x361.2 = x.1  :: array(float64, 1d, C, nonconst)
#             #   $k361.3 = k  :: int64
#             #   $361.6 = getitem(index=k, value=x.1)  :: float64
#             #   $361.9 = getitem(index=i, value=x.1)  :: float64
#             #   $361.13 = build_tuple(items=[Var(i, gth_solve_jit.py (133)), Var(k, gth_solve_jit.py (132))])  :: (int64 x 2)
#             #   del i
#             #   $361.14 = getitem(index=$361.13, value=A1.1)  :: float64
#             #   del $361.13
#             #   $361.15 = $361.9 * $361.14  :: float64
#             #   del $361.9
#             #   del $361.14
#             #   $361.16 = inplace_binop(rhs=$361.15, lhs=$361.6, fn=+)  :: float64
#             #   del $361.6
#             #   del $361.15
#             #   $x361.2[$k361.3] = $361.16  :: (array(float64, 1d, C, nonconst), int64, float64) -> none
#             #   del $x361.2
#             #   del $k361.3
#             #   del $361.16
#             #   jump 358
#             # label 402
#             #   jump 332
#             # label 401
#             #   del k
#             #   del $phi361.1
#             #   del $phi358.1
#             #   del $358.4
#             #   jump 402
#             # label 406
#             #   $const406.1 = const(NoneType, None)  :: none
#             #   $406.2 = cast(value=$const406.1)  :: none
#             #   del $const406.1
#             #   return $406.2
#             # label 405
#             #   del x.1
#             #   del n.1
#             #   del A1.1
#             #   del $phi335.1
#             #   del $phi332.1
#             #   del $332.4
#             #   jump 406
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
# # Loop at line 138
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#     # label 434
#     #   $434.2 = iternext(value=$phi434.1)  :: pair<int64, bool>
#     #   $434.3 = pair_first(value=$434.2)  :: int64
#     #   $434.4 = pair_second(value=$434.2)  :: bool
#     #   del $434.2
#     #   $phi437.1 = $434.3  :: int64
#     #   del $434.3
#     #   branch $434.4, 437, 459
#     # label 421
#     #   x.1 = x  :: array(float64, 1d, C, nonconst)
#     #   del x
#     #   norm.1 = norm  :: float64
#     #   del norm
#     #   n.1 = n  :: int64
#     #   del n
#     #   $421.1 = global(range: <built-in function range>)  :: range
#     #   $421.3 = call $421.1(n.1, )  :: (int64,) -> range_state64
#     #   del n.1
#     #   del $421.1
#     #   $421.4 = getiter(value=$421.3)  :: range_iter64
#     #   del $421.3
#     #   $phi434.1 = $421.4  :: range_iter64
#     #   del $421.4
#     #   jump 434
#     # label 437
#     #   k = $phi437.1  :: int64
#     #   del $phi437.1
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#         # label 459
#         #   del x.1
#         #   del norm.1
#         #   del $phi437.1
#         #   del $phi434.1
#         #   del $434.4
#         #   jump 460
#         # label 460
#         #   $const460.1 = const(NoneType, None)  :: none
#         #   $460.2 = cast(value=$const460.1)  :: none
#         #   del $const460.1
#         #   return $460.2
#         #   $x437.2 = x.1  :: array(float64, 1d, C, nonconst)
#         #   $k437.3 = k  :: int64
#         #   $437.6 = getitem(index=k, value=x.1)  :: float64
#         #   del k
#         #   $437.8 = inplace_binop(rhs=norm.1, lhs=$437.6, fn=/?)  :: float64
#         #   del $437.6
#         #   $x437.2[$k437.3] = $437.8  :: (array(float64, 1d, C, nonconst), int64, float64) -> none
#         #   del $x437.2
#         #   del $k437.3
#         #   del $437.8
#         #   jump 434
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
#
# ================================================================================
# gth_solve_jit (pyobject,)
# --------------------------------------------------------------------------------
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#     # label 0
#     #   A.1 = A  :: pyobject
#     #   del A
#     #   $0.1 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $0.2 = getattr(attr=array, value=$0.1)  :: pyobject
#     #   del $0.1
#     #   $0.5 = global(float: <type 'float'>)  :: pyobject
#     #   $0.6 = call $0.2(A.1, dtype=$0.5)  :: pyobject
#     #   del A.1
#     #   del $0.5
#     #   del $0.2
#     #   A1 = $0.6  :: pyobject
#     #   del $0.6
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#     #   $0.7 = global(len: <built-in function len>)  :: pyobject
#     #   $0.9 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $0.10 = call $0.7($0.9, )  :: pyobject
#     #   del $0.9
#     #   del $0.7
#     #   $const0.11 = const(int, 2)  :: pyobject
#     #   $0.12 = $0.10 != $const0.11  :: pyobject
#     #   del $const0.11
#     #   del $0.10
#     #   branch $0.12, 68, 42
#     # label 42
#     #   $42.2 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const42.3 = const(int, 0)  :: pyobject
#     #   $42.4 = getitem(index=$const42.3, value=$42.2)  :: pyobject
#     #   del $const42.3
#     #   del $42.2
#     #   $42.6 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const42.7 = const(int, 1)  :: pyobject
#     #   $42.8 = getitem(index=$const42.7, value=$42.6)  :: pyobject
#     #   del $const42.7
#     #   del $42.6
#     #   $42.9 = $42.4 != $42.8  :: pyobject
#     #   del $42.8
#     #   del $42.4
#     #   branch $42.9, 68, 77
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#         # label 68
#         #   del A1
#         #   del $42.9
#         #   del $0.12
#         #   $68.1 = global(ValueError: <type 'exceptions.ValueError'>)  :: pyobject
#         #   del $68.1
#         #   raise <type 'exceptions.ValueError'>
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#     # label 77
#     #   del $42.9
#     #   del $0.12
#     #   $77.2 = getattr(attr=shape, value=A1)  :: pyobject
#     #   $const77.3 = const(int, 0)  :: pyobject
#     #   $77.4 = getitem(index=$const77.3, value=$77.2)  :: pyobject
#     #   del $const77.3
#     #   del $77.2
#     #   n = $77.4  :: pyobject
#     #   del $77.4
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#     #   $77.5 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $77.6 = getattr(attr=zeros, value=$77.5)  :: pyobject
#     #   del $77.5
#     #   $77.8 = call $77.6(n, )  :: pyobject
#     #   del $77.6
#     #   x = $77.8  :: pyobject
#     #   del $77.8
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#     # label 108.1
#     #   $const108.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $108.1.4 = call $const108.1.1(A1, n, )  :: pyobject
#     #   del $const108.1.1
#     #   del $108.1.4
#     #   jump 295
#     #   jump 108.1
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#     # label 295
#     #   $const295.1 = const(int, 1)  :: pyobject
#     #   $const295.4 = const(int, 1)  :: pyobject
#     #   $295.5 = n - $const295.4  :: pyobject
#     #   del $const295.4
#     #   x[$295.5] = $const295.1  :: pyobject
#     #   del $const295.1
#     #   del $295.5
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#     #   jump 312.1
#     # label 312.1
#     #   $const312.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $312.1.5 = call $const312.1.1(A1, x, n, )  :: pyobject
#     #   del A1
#     #   del $const312.1.1
#     #   del $312.1.5
#     #   jump 406
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#     # label 406
#     #   $406.1 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: pyobject
#     #   $406.2 = getattr(attr=sum, value=$406.1)  :: pyobject
#     #   del $406.1
#     #   $406.4 = call $406.2(x, )  :: pyobject
#     #   del $406.2
#     #   norm = $406.4  :: pyobject
#     #   del $406.4
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#     # label 424.1
#     #   $const424.1.1 = const(LiftedLoop, LiftedLoop(<function gth_solve_jit at 0x1089611b8>))  :: pyobject
#     #   $424.1.5 = call $const424.1.1(x, norm, n, )  :: pyobject
#     #   del norm
#     #   del n
#     #   del $const424.1.1
#     #   del $424.1.5
#     #   jump 460
#     #   jump 424.1
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#     # label 460
#     #   $460.2 = cast(value=x)  :: pyobject
#     #   del x
#     #   return $460.2
#
#     return x
#
# # The function contains lifted loops
# # Loop at line 116
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#     # label 105
#     #   A1.1 = A1  :: array(float64, 2d, C, nonconst)
#     #   del A1
#     #   n.1 = n  :: int64
#     #   del n
#     #   $105.1 = global(range: <built-in function range>)  :: range
#     #   $const105.3 = const(int, 1)  :: int32
#     #   $105.4 = n.1 - $const105.3  :: int64
#     #   del $const105.3
#     #   $105.5 = call $105.1($105.4, )  :: (int64,) -> range_state64
#     #   del $105.4
#     #   del $105.1
#     #   $105.6 = getiter(value=$105.5)  :: range_iter64
#     #   del $105.5
#     #   $phi122.1 = $105.6  :: range_iter64
#     #   del $105.6
#     #   jump 122
#     # label 125
#     #   k = $phi125.1  :: int64
#     #   del $phi125.1
#     # label 122
#     #   $122.2 = iternext(value=$phi122.1)  :: pair<int64, bool>
#     #   $122.3 = pair_first(value=$122.2)  :: int64
#     #   $122.4 = pair_second(value=$122.2)  :: bool
#     #   del $122.2
#     #   $phi125.1 = $122.3  :: int64
#     #   del $122.3
#     #   branch $122.4, 125, 294
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#         #   $125.2 = global(np: <module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)  :: Module(<module 'numpy' from '/usr/local/lib/python2.7/site-packages/numpy/__init__.pyc'>)
#         #   $125.3 = getattr(attr=sum, value=$125.2)  :: Function(<unbound method Numpy_reduce_<function sum at 0x103db1848>.sum>)
#         #   del $125.2
#         #   $k125.5 = k  :: int64
#         #   $const125.7 = const(int, 1)  :: int32
#         #   $125.8 = k + $const125.7  :: int64
#         #   del $const125.7
#         #   $125.10 = global(slice: <type 'slice'>)  :: slice
#         #   $125.11 = call $125.10($125.8, n.1, )  :: (int64, int64) -> slice3_type
#         #   del $125.8
#         #   del $125.10
#         #   $125.12 = build_tuple(items=[Var($k125.5, gth_solve_jit.py (117)), Var($125.11, gth_solve_jit.py (117))])  :: (int64, slice3_type)
#         #   del $k125.5
#         #   del $125.11
#         #   $125.13 = getitem(index=$125.12, value=A1.1)  :: array(float64, 1d, A, nonconst)
#         #   del $125.12
#         #   $125.14 = call $125.3($125.13, )  :: (array(float64, 1d, A, nonconst),) -> float64
#         #   del $125.3
#         #   del $125.13
#         #   scale = $125.14  :: float64
#         #   del $125.14
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#         # label 163
#         #   $163.1 = global(range: <built-in function range>)  :: range
#         #   $const163.3 = const(int, 1)  :: int32
#         #   $163.4 = k + $const163.3  :: int64
#         #   del $const163.3
#         #   $163.6 = call $163.1($163.4, n.1, )  :: (int64, int64) -> range_state64
#         #   del $163.4
#         #   del $163.1
#         #   $163.7 = getiter(value=$163.6)  :: range_iter64
#         #   del $163.6
#         #   $phi183.1 = $163.7  :: range_iter64
#         #   del $163.7
#         #   jump 183
#         #   jump 163
#         # label 183
#         #   $183.2 = iternext(value=$phi183.1)  :: pair<int64, bool>
#         #   $183.3 = pair_first(value=$183.2)  :: int64
#         #   $183.4 = pair_second(value=$183.2)  :: bool
#         #   del $183.2
#         #   $phi186.1 = $183.3  :: int64
#         #   del $183.3
#         #   branch $183.4, 186, 290
#         # label 186
#         #   i = $phi186.1  :: int64
#         #   del $phi186.1
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#             #   $A1186.2 = A1.1  :: array(float64, 2d, C, nonconst)
#             #   $186.5 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(k, gth_solve_jit.py (116))])  :: (int64 x 2)
#             #   $186.8 = getitem(index=$186.5, value=A1.1)  :: float64
#             #   $186.10 = inplace_binop(rhs=scale, lhs=$186.8, fn=/?)  :: float64
#             #   del $186.8
#             #   $A1186.2[$186.5] = $186.10  :: (array(float64, 2d, C, nonconst), (int64 x 2), float64) -> none
#             #   del $A1186.2
#             #   del $186.5
#             #   del $186.10
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#             # label 231
#             #   $231.2 = iternext(value=$phi231.1)  :: pair<int64, bool>
#             #   $231.3 = pair_first(value=$231.2)  :: int64
#             #   $231.4 = pair_second(value=$231.2)  :: bool
#             #   del $231.2
#             #   $phi234.1 = $231.3  :: int64
#             #   del $231.3
#             #   branch $231.4, 234, 286
#             # label 234
#             #   j = $phi234.1  :: int64
#             #   del $phi234.1
#             # label 211
#             #   $211.1 = global(range: <built-in function range>)  :: range
#             #   $const211.3 = const(int, 1)  :: int32
#             #   $211.4 = k + $const211.3  :: int64
#             #   del $const211.3
#             #   $211.6 = call $211.1($211.4, n.1, )  :: (int64, int64) -> range_state64
#             #   del $211.4
#             #   del $211.1
#             #   $211.7 = getiter(value=$211.6)  :: range_iter64
#             #   del $211.6
#             #   $phi231.1 = $211.7  :: range_iter64
#             #   del $211.7
#             #   jump 231
#             #   jump 211
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#                 # label 290
#                 #   del scale
#                 #   del k
#                 #   del $phi186.1
#                 #   del $phi183.1
#                 #   del $183.4
#                 #   jump 291
#                 # label 294
#                 #   del n.1
#                 #   del A1.1
#                 #   del $phi125.1
#                 #   del $phi122.1
#                 #   del $122.4
#                 #   jump 295
#                 #   $A1234.2 = A1.1  :: array(float64, 2d, C, nonconst)
#                 #   $234.5 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(j, gth_solve_jit.py (127))])  :: (int64 x 2)
#                 #   $234.8 = getitem(index=$234.5, value=A1.1)  :: float64
#                 #   $234.12 = build_tuple(items=[Var(i, gth_solve_jit.py (124)), Var(k, gth_solve_jit.py (116))])  :: (int64 x 2)
#                 #   $234.13 = getitem(index=$234.12, value=A1.1)  :: float64
#                 #   del $234.12
#                 #   $234.17 = build_tuple(items=[Var(k, gth_solve_jit.py (116)), Var(j, gth_solve_jit.py (127))])  :: (int64 x 2)
#                 #   del j
#                 #   $234.18 = getitem(index=$234.17, value=A1.1)  :: float64
#                 #   del $234.17
#                 #   $234.19 = $234.13 * $234.18  :: float64
#                 #   del $234.18
#                 #   del $234.13
#                 #   $234.20 = inplace_binop(rhs=$234.19, lhs=$234.8, fn=+)  :: float64
#                 #   del $234.8
#                 #   del $234.19
#                 #   $A1234.2[$234.5] = $234.20  :: (array(float64, 2d, C, nonconst), (int64 x 2), float64) -> none
#                 #   del $A1234.2
#                 #   del $234.5
#                 #   del $234.20
#                 #   jump 231
#                 # label 295
#                 #   $const295.1 = const(NoneType, None)  :: none
#                 #   $295.2 = cast(value=$const295.1)  :: none
#                 #   del $const295.1
#                 #   return $295.2
#                 # label 291
#                 #   jump 122
#                 # label 286
#                 #   del i
#                 #   del $phi234.1
#                 #   del $phi231.1
#                 #   del $231.4
#                 #   jump 287
#                 # label 287
#                 #   jump 183
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
# # Loop at line 132
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#     # label 332
#     #   $332.2 = iternext(value=$phi332.1)  :: pair<int64, bool>
#     #   $332.3 = pair_first(value=$332.2)  :: int64
#     #   $332.4 = pair_second(value=$332.2)  :: bool
#     #   del $332.2
#     #   $phi335.1 = $332.3  :: int64
#     #   del $332.3
#     #   branch $332.4, 335, 405
#     # label 335
#     #   k = $phi335.1  :: int64
#     #   del $phi335.1
#     # label 309
#     #   A1.1 = A1  :: array(float64, 2d, C, nonconst)
#     #   del A1
#     #   x.1 = x  :: array(float64, 1d, C, nonconst)
#     #   del x
#     #   n.1 = n  :: int64
#     #   del n
#     #   $309.1 = global(range: <built-in function range>)  :: range
#     #   $const309.3 = const(int, 2)  :: int32
#     #   $309.4 = n.1 - $const309.3  :: int64
#     #   del $const309.3
#     #   $const309.5 = const(int, -1)  :: int32
#     #   $const309.6 = const(int, -1)  :: int32
#     #   $309.7 = call $309.1($309.4, $const309.5, $const309.6, )  :: (int64, int64, int64) -> range_state64
#     #   del $const309.6
#     #   del $const309.5
#     #   del $309.4
#     #   del $309.1
#     #   $309.8 = getiter(value=$309.7)  :: range_iter64
#     #   del $309.7
#     #   $phi332.1 = $309.8  :: range_iter64
#     #   del $309.8
#     #   jump 332
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#         # label 358
#         #   $358.2 = iternext(value=$phi358.1)  :: pair<int64, bool>
#         #   $358.3 = pair_first(value=$358.2)  :: int64
#         #   $358.4 = pair_second(value=$358.2)  :: bool
#         #   del $358.2
#         #   $phi361.1 = $358.3  :: int64
#         #   del $358.3
#         #   branch $358.4, 361, 401
#         # label 361
#         #   i = $phi361.1  :: int64
#         #   del $phi361.1
#         #   jump 338
#         # label 338
#         #   $338.1 = global(range: <built-in function range>)  :: range
#         #   $const338.3 = const(int, 1)  :: int32
#         #   $338.4 = k + $const338.3  :: int64
#         #   del $const338.3
#         #   $338.6 = call $338.1($338.4, n.1, )  :: (int64, int64) -> range_state64
#         #   del $338.4
#         #   del $338.1
#         #   $338.7 = getiter(value=$338.6)  :: range_iter64
#         #   del $338.6
#         #   $phi358.1 = $338.7  :: range_iter64
#         #   del $338.7
#         #   jump 358
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#             #   $x361.2 = x.1  :: array(float64, 1d, C, nonconst)
#             #   $k361.3 = k  :: int64
#             #   $361.6 = getitem(index=k, value=x.1)  :: float64
#             #   $361.9 = getitem(index=i, value=x.1)  :: float64
#             #   $361.13 = build_tuple(items=[Var(i, gth_solve_jit.py (133)), Var(k, gth_solve_jit.py (132))])  :: (int64 x 2)
#             #   del i
#             #   $361.14 = getitem(index=$361.13, value=A1.1)  :: float64
#             #   del $361.13
#             #   $361.15 = $361.9 * $361.14  :: float64
#             #   del $361.9
#             #   del $361.14
#             #   $361.16 = inplace_binop(rhs=$361.15, lhs=$361.6, fn=+)  :: float64
#             #   del $361.6
#             #   del $361.15
#             #   $x361.2[$k361.3] = $361.16  :: (array(float64, 1d, C, nonconst), int64, float64) -> none
#             #   del $x361.2
#             #   del $k361.3
#             #   del $361.16
#             #   jump 358
#             # label 402
#             #   jump 332
#             # label 401
#             #   del k
#             #   del $phi361.1
#             #   del $phi358.1
#             #   del $358.4
#             #   jump 402
#             # label 406
#             #   $const406.1 = const(NoneType, None)  :: none
#             #   $406.2 = cast(value=$const406.1)  :: none
#             #   del $const406.1
#             #   return $406.2
#             # label 405
#             #   del x.1
#             #   del n.1
#             #   del A1.1
#             #   del $phi335.1
#             #   del $phi332.1
#             #   del $332.4
#             #   jump 406
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
# # Loop at line 138
# # Has 1 overloads
# # File: gth_solve_jit.py
# # --- LINE 97 ---
#
# @jit
#
# # --- LINE 98 ---
#
# def gth_solve_jit(A):
#
#     # --- LINE 99 ---
#
#     """
#
#     # --- LINE 100 ---
#
#     JIT-compiled version of `gth_solve`.
#
# # --- LINE 101 ---
#
#
#
#     # --- LINE 102 ---
#
#     """
#
#     # --- LINE 103 ---
#
#     #A1 = np.array(A, dtype=np.float64)
#
#     # --- LINE 104 ---
#
#     A1 = np.array(A, dtype=float)
#
# # --- LINE 105 ---
#
#
#
#     # --- LINE 106 ---
#
#     if len(A1.shape) != 2 or A1.shape[0] != A1.shape[1]:
#
#         # --- LINE 107 ---
#
#         # raise ValueError('matrix must be square')  # Not supported
#
#         # --- LINE 108 ---
#
#         raise ValueError
#
# # --- LINE 109 ---
#
#
#
#     # --- LINE 110 ---
#
#     n = A1.shape[0]
#
# # --- LINE 111 ---
#
#
#
#     # --- LINE 112 ---
#
#     #x = np.zeros(n, dtype=np.float64)
#
#     # --- LINE 113 ---
#
#     x = np.zeros(n)
#
# # --- LINE 114 ---
#
#
#
#     # --- LINE 115 ---
#
#     # === Reduction === #
#
#     # --- LINE 116 ---
#
#     for k in range(n-1):
#
#         # --- LINE 117 ---
#
#         scale = np.sum(A1[k, k+1:n])
#
#         # --- LINE 118 ---
#
#         #if scale <= 0:
#
#         # --- LINE 119 ---
#
#         #    # There is one (and only one) recurrent class contained in
#
#         # --- LINE 120 ---
#
#         #    # {0, ..., k};
#
#         # --- LINE 121 ---
#
#         #    # compute the solution associated with that recurrent class.
#
#         # --- LINE 122 ---
#
#         #    n = k+1
#
#         # --- LINE 123 ---
#
#         #    break
#
#         # --- LINE 124 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 125 ---
#
#             A1[i, k] /= scale
#
# # --- LINE 126 ---
#
#
#
#             # --- LINE 127 ---
#
#             for j in range(k+1, n):
#
#                 # --- LINE 128 ---
#
#                 A1[i, j] += A1[i, k] * A1[k, j]
#
# # --- LINE 129 ---
#
#
#
#     # --- LINE 130 ---
#
#     # === Backward substitution === #
#
#     # --- LINE 131 ---
#
#     x[n-1] = 1
#
#     # --- LINE 132 ---
#
#     for k in range(n-2, -1, -1):
#
#         # --- LINE 133 ---
#
#         for i in range(k+1, n):
#
#             # --- LINE 134 ---
#
#             x[k] += x[i] * A1[i, k]
#
# # --- LINE 135 ---
#
#
#
#     # --- LINE 136 ---
#
#     # === Normalization === #
#
#     # --- LINE 137 ---
#
#     norm = np.sum(x)
#
#     # --- LINE 138 ---
#     # label 434
#     #   $434.2 = iternext(value=$phi434.1)  :: pair<int64, bool>
#     #   $434.3 = pair_first(value=$434.2)  :: int64
#     #   $434.4 = pair_second(value=$434.2)  :: bool
#     #   del $434.2
#     #   $phi437.1 = $434.3  :: int64
#     #   del $434.3
#     #   branch $434.4, 437, 459
#     # label 421
#     #   x.1 = x  :: array(float64, 1d, C, nonconst)
#     #   del x
#     #   norm.1 = norm  :: float64
#     #   del norm
#     #   n.1 = n  :: int64
#     #   del n
#     #   $421.1 = global(range: <built-in function range>)  :: range
#     #   $421.3 = call $421.1(n.1, )  :: (int64,) -> range_state64
#     #   del n.1
#     #   del $421.1
#     #   $421.4 = getiter(value=$421.3)  :: range_iter64
#     #   del $421.3
#     #   $phi434.1 = $421.4  :: range_iter64
#     #   del $421.4
#     #   jump 434
#     # label 437
#     #   k = $phi437.1  :: int64
#     #   del $phi437.1
#
#     for k in range(n):
#
#         # --- LINE 139 ---
#         # label 459
#         #   del x.1
#         #   del norm.1
#         #   del $phi437.1
#         #   del $phi434.1
#         #   del $434.4
#         #   jump 460
#         # label 460
#         #   $const460.1 = const(NoneType, None)  :: none
#         #   $460.2 = cast(value=$const460.1)  :: none
#         #   del $const460.1
#         #   return $460.2
#         #   $x437.2 = x.1  :: array(float64, 1d, C, nonconst)
#         #   $k437.3 = k  :: int64
#         #   $437.6 = getitem(index=k, value=x.1)  :: float64
#         #   del k
#         #   $437.8 = inplace_binop(rhs=norm.1, lhs=$437.6, fn=/?)  :: float64
#         #   del $437.6
#         #   $x437.2[$k437.3] = $437.8  :: (array(float64, 1d, C, nonconst), int64, float64) -> none
#         #   del $x437.2
#         #   del $k437.3
#         #   del $437.8
#         #   jump 434
#
#         x[k] /= norm
#
# # --- LINE 140 ---
#
#
#
#     # --- LINE 141 ---
#
#     return x
#
#
#
# ================================================================================
